# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn import cluster
from scipy import stats  ## for z-score. do we still need it?

# %%
# Read Scan On Data
scanOn_samp0 = pd.read_csv('all_scanOn_samp0.csv')

scanOn_samp0.head()
# Out:
#    Mode BusinessDate             DateTime    CardID  CardType  VehicleID  \
# 0     1   2015-07-02  2015-07-02 13:08:13   1524480         9       1222
# 1     3   2015-07-02  2015-07-02 07:33:58   1756270         2       1091
# 2     1   2015-07-02  2015-07-02 16:42:38  10560630         2       1469
# 3     1   2015-07-01  2015-07-01 11:07:08  11812440         2       2886
# 4     1   2015-07-01  2015-07-01 17:28:14  12272500         2       2853
#
#   ParentRoute  RouteID  StopID
# 0         415    10883   15084
# 1          24    15296   18566
# 2         862    10227   19824
# 3         458     8591   21184
# 4         670    16447   21296

# %%
for col in scanOn_samp0.columns:
    if (scanOn_samp0[col].dtype.name in ['category', 'str', 'object']):
        # Check for extra whitespaces and remove them
        scanOn_samp0[col] = scanOn_samp0[col].str.strip()

# %%
# Read card types
column_names = ("Card_SubType_ID","Card_SubType_Desc","Payment_Type","Fare_Type","Concession_Type","MI_Card_Group")
card_types = pd.read_csv('card_types.txt',sep="|", names=column_names)

card_types.head()
# Out:
#    Card_SubType_ID                    Card_SubType_Desc Payment_Type  \
# 0               62  Pensioner Concession Card holder PC         Paid
# 1               29         Vic HCC - Sickness allowance         Paid
# 2               43                     First Class Pass         Free
# 3               34                PCC - Widow allowance         Paid
# 4               47     Victoria Police Travel Authority         Free
#
#     Fare_Type   Concession_Type     MI_Card_Group
# 0  Concession  Other Concession  Other Concession
# 1  Concession  Other Concession  Other Concession
# 2  Concession         Free Pass             Other
# 3  Concession  Other Concession  Other Concession
# 4  Concession         Free Pass             Other

# %%
# Read stop locations
column_names = ("StopLocationID","StopNameShort","StopNameLong","StopType","SuburbName","PostCode","RegionName","LocalGovernmentArea","StatDivision","GPSLat","GPSLong")
stop_locations = pd.read_csv('stop_locations.txt',sep="|", names=column_names)

stop_locations.head()
# Out:
#    StopLocationID       StopNameShort  \
# 0             867       Weemala Court
# 1             868         Crana Grove
# 2             869    Punkerri Circuit
# 3             870  Plenty River Drive
# 4             875         Oldstead Rd
#
#                                    StopNameLong  StopType     SuburbName  \
# 0    Weemala Ct/Plenty River Dr (Greensborough)  Kerbside  Greensborough
# 1      Crana Gr/Plenty River Dr (Greensborough)  Kerbside  Greensborough
# 2  Punkerri Cct/Plenty River Dr (Greensborough)  Kerbside  Greensborough
# 3           231 Plenty River Dr (Greensborough)  Kerbside  Greensborough
# 4  Oldstead Rd/Diamond Creek Rd (Greensborough)  Kerbside  Greensborough
#
#    PostCode RegionName LocalGovernmentArea   StatDivision     GPSLat  \
# 0    3088.0  Melbourne             Banyule  Greater Metro -37.689596
# 1    3088.0  Melbourne             Banyule  Greater Metro -37.686742
# 2    3088.0  Melbourne             Banyule  Greater Metro -37.683643
# 3    3088.0  Melbourne             Banyule  Greater Metro -37.682591
# 4    3088.0  Melbourne             Banyule  Greater Metro -37.685336
#
#       GPSLong
# 0  145.105088
# 1  145.105588
# 2  145.108743
# 3  145.111331
# 4  145.117319

# %%
# Read calendar
column_names = ("CalendarDateSeq","Date","CalendarYear","FinancialYear","FinancialMonth","CalendarMonth","CalendarMonthSeq","CalendarQuarter","FinancialQuarter","CalendarWeek","FinancialWeek","DayType","DayTypeCategory","DayTypeAdditional","WeekdaySeq","WeekDay","FinancialMonthSeq","FinancialMonthName","MonthNumber","ABSWeek","WeekEnding","QuarterName")
calendar = pd.read_csv('calendar.txt',sep="|", names=column_names, encoding='utf-8')
#list(calendar)
calendar.head()
# Out:
#    CalendarDateSeq        Date  CalendarYear  FinancialYear  FinancialMonth  \
# 0         20170930  2017-09-30          2017  FY2017 - 2018               9
# 1         20080615  2008-06-15          2008  FY2007 - 2008              18
# 2         20040222  2004-02-22          2004  FY2003 - 2004              14
# 3         20190620  2019-06-20          2019  FY2018 - 2019              18
# 4         20170831  2017-08-31          2017  FY2017 - 2018               8
#
#   CalendarMonth  CalendarMonthSeq CalendarQuarter FinancialQuarter  \
# 0     September            201709          2017Q3        FY17-18Q1
# 1          June            200806          2008Q2        FY07-08Q4
# 2      February            200402          2004Q1        FY03-04Q3
# 3          June            201906          2019Q2        FY18-19Q4
# 4        August            201708          2017Q3        FY17-18Q1
#
#    CalendarWeek         ...           DayTypeCategory DayTypeAdditional  \
# 0            39         ...                   Weekend          Saturday
# 1            24         ...                   Weekend            Sunday
# 2             8         ...                   Weekend     Normal Sunday
# 3            24         ...                   Weekday                 0
# 4            35         ...                   Weekday    Normal Weekday
#
#   WeekdaySeq   WeekDay  FinancialMonthSeq FinancialMonthName  MonthNumber  \
# 0          6  Saturday             201709            Sep 17/            9
# 1          7    Sunday             200818            Jun 07/            6
# 2          7    Sunday             200414            Feb 03/            2
# 3          4  Thursday             201906            Jun 18/            6
# 4          4  Thursday             201708            Aug 17/            8
#
#   ABSWeek      WeekEnding          QuarterName
# 0    1239  w/e 2017-09-30  September Qtr. 2017
# 1     755  w/e 2008-06-21       June Qtr. 2008
# 2     530  w/e 2004-02-28      March Qtr. 2004
# 3    1329  w/e 2019-06-22       June Qtr. 2019
# 4    1235  w/e 2017-09-02  September Qtr. 2017
#
# [5 rows x 22 columns]

# %%
# Some data preperation of scanOn_samp0 data

# %%
scanOn_samp0.isnull().sum()
# Out:
# Mode                 0
# BusinessDate         0
# DateTime             0
# CardID               0
# CardType             0
# VehicleID            0
# ParentRoute     993734
# RouteID              0
# StopID               0
# dtype: int64

# %%
# Check for missing values and replace with 0
scanOn_samp0.ParentRoute.fillna(0, inplace=True)
print ('Replaced missing values with 0')
# Out:
# Replaced missing values with 0

# %%
# Some data prep on calendar data

calendar.WeekEnding = calendar.WeekEnding.str.replace('w/e ', '')
calendar.FinancialMonthName = calendar.FinancialMonthName.str.replace('/','')
calendar.WeekEnding.value_counts()
calendar.FinancialMonthName.value_counts()

calendar.head()
# Out:
#    CalendarDateSeq        Date  CalendarYear  FinancialYear  FinancialMonth  \
# 0         20170930  2017-09-30          2017  FY2017 - 2018               9
# 1         20080615  2008-06-15          2008  FY2007 - 2008              18
# 2         20040222  2004-02-22          2004  FY2003 - 2004              14
# 3         20190620  2019-06-20          2019  FY2018 - 2019              18
# 4         20170831  2017-08-31          2017  FY2017 - 2018               8
#
#   CalendarMonth  CalendarMonthSeq CalendarQuarter FinancialQuarter  \
# 0     September            201709          2017Q3        FY17-18Q1
# 1          June            200806          2008Q2        FY07-08Q4
# 2      February            200402          2004Q1        FY03-04Q3
# 3          June            201906          2019Q2        FY18-19Q4
# 4        August            201708          2017Q3        FY17-18Q1
#
#    CalendarWeek         ...           DayTypeCategory DayTypeAdditional  \
# 0            39         ...                   Weekend          Saturday
# 1            24         ...                   Weekend            Sunday
# 2             8         ...                   Weekend     Normal Sunday
# 3            24         ...                   Weekday                 0
# 4            35         ...                   Weekday    Normal Weekday
#
#   WeekdaySeq   WeekDay  FinancialMonthSeq FinancialMonthName  MonthNumber  \
# 0          6  Saturday             201709             Sep 17            9
# 1          7    Sunday             200818             Jun 07            6
# 2          7    Sunday             200414             Feb 03            2
# 3          4  Thursday             201906             Jun 18            6
# 4          4  Thursday             201708             Aug 17            8
#
#   ABSWeek  WeekEnding          QuarterName
# 0    1239  2017-09-30  September Qtr. 2017
# 1     755  2008-06-21       June Qtr. 2008
# 2     530  2004-02-28      March Qtr. 2004
# 3    1329  2019-06-22       June Qtr. 2019
# 4    1235  2017-09-02  September Qtr. 2017
#
# [5 rows x 22 columns]

# %%
# Save dataframes to csv

scanOn_samp0.to_csv('scanOn_samp0_processed.csv', index=False)
card_types.to_csv('card_types_processed.csv', index=False)
stop_locations.to_csv('stop_locations_processed.csv', index=False)
calendar.to_csv('calendar_processed.csv', index=False)

# %%
scanOn_samp0.size
# Out:
# 14130000

# %%
# Read speeds
speeds = pd.read_csv('melbourne_vehicle_traffic.csv',sep=",")

speeds.head()
# Out:
#    location index        lat         lon  \
# 0               0 -38.100617  145.488326
# 1               1 -38.062604  145.367474
# 2               2 -38.357822  144.757135
# 3               3 -38.355186  144.752776
# 4               4 -38.351950  144.918912
#
#                                           mean_speed  \
# 0  [73.82, 82.73, 84.695, 79.11, 76.4425, 66.62, ...
# 1  [56.12142857142857, 56.995000000000005, 70.156...
# 2  [65.52666666666666, 59.155, 46.449999999999996...
# 3  [76.262, 72.418, 68.33, 73.508, 77.43, 76.47, ...
# 4  [58.82400000000001, 55.13249999999999, 50.8799...
#
#                                            std_speed
# 0  [0.0, 0.0, 5.225000000000001, 11.5499999999999...
# 1  [11.149351587259527, 23.845000000000002, 9.831...
# 2  [2.6402819714736676, 2.6219982837522977, 17.92...
# 3  [1.930444508396961, 2.806730482251543, 4.72478...
# 4  [4.580648862333807, 4.693273777439369, 18.3136...

# %%
speeds['week_hour'] = 0

speeds.head()

headers = speeds.dtypes.index

speeds_ = pd.DataFrame(data=None, index=None, columns=headers, dtype=None, copy=False)

speeds_.head()
# Out:
# Empty DataFrame
# Columns: [location index, lat, lon, mean_speed, std_speed, week_hour]
# Index: []

# %%
for index, row in speeds.iterrows():
    label = 'mean_speed'
    s = speeds[label].iloc[index]
    s = s[1:(len(s)-1)]
    L = s.split(", ")
    for idx, val in enumerate(L):
        row[3] = val
        row[5] = idx
        #print(row[1])
        speeds_ = speeds_.append(row, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-00505d4a907c> in <module>()
#       8         row[5] = idx
#       9         #print(row[1])
# ---> 10         speeds_ = speeds_.append(row, ignore_index=True)
#      11
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6199         return concat(to_concat, ignore_index=ignore_index,
#    6200                       verify_integrity=verify_integrity,
# -> 6201                       sort=sort)
#    6202
#    6203     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     287
#     288             # consolidate
# --> 289             obj._consolidate(inplace=True)
#     290             ndims.add(obj.ndim)
#     291
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _consolidate(self, inplace)
#    4451         inplace = validate_bool_kwarg(inplace, 'inplace')
#    4452         if inplace:
# -> 4453             self._consolidate_inplace()
#    4454         else:
#    4455             f = lambda: self._data.consolidate()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    4433             self._data = self._data.consolidate()
#    4434
# -> 4435         self._protect_consolidate(f)
#    4436
#    4437     def _consolidate(self, inplace=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    4422         """
#    4423         blocks_before = len(self._data.blocks)
# -> 4424         result = f()
#    4425         if len(self._data.blocks) != blocks_before:
#    4426             self._clear_item_cache()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in f()
#    4431
#    4432         def f():
# -> 4433             self._data = self._data.consolidate()
#    4434
#    4435         self._protect_consolidate(f)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in consolidate(self)
#    4096         bm = self.__class__(self.blocks, self.axes)
#    4097         bm._is_consolidated = False
# -> 4098         bm._consolidate_inplace()
#    4099         return bm
#    4100
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _consolidate_inplace(self)
#    4101     def _consolidate_inplace(self):
#    4102         if not self.is_consolidated():
# -> 4103             self.blocks = tuple(_consolidate(self.blocks))
#    4104             self._is_consolidated = True
#    4105             self._known_consolidated = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _consolidate(blocks)
#    5067     for (_can_consolidate, dtype), group_blocks in grouper:
#    5068         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 5069                                       _can_consolidate=_can_consolidate)
#    5070         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    5071     return new_blocks
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    5090
#    5091         argsort = np.argsort(new_mgr_locs)
# -> 5092         new_values = new_values[argsort]
#    5093         new_mgr_locs = new_mgr_locs[argsort]
#    5094
#
# KeyboardInterrupt:

# %%
speeds_.head()
# Out:
#   location index        lat         lon mean_speed  \
# 0              0 -38.100617  145.488326      73.82
# 1              0 -38.100617  145.488326      82.73
# 2              0 -38.100617  145.488326     84.695
# 3              0 -38.100617  145.488326      79.11
# 4              0 -38.100617  145.488326    76.4425
#
#                                            std_speed week_hour
# 0  [0.0, 0.0, 5.225000000000001, 11.5499999999999...         0
# 1  [0.0, 0.0, 5.225000000000001, 11.5499999999999...         1
# 2  [0.0, 0.0, 5.225000000000001, 11.5499999999999...         2
# 3  [0.0, 0.0, 5.225000000000001, 11.5499999999999...         3
# 4  [0.0, 0.0, 5.225000000000001, 11.5499999999999...         4

# %%
#speeds['mean_speed'] = speeds['mean_speed'].map(lambda x: x.lstrip('[').rstrip(']'))
#speeds['std_speed'] = speeds['std_speed'].map(lambda x: x.lstrip('[').rstrip(']'))
speeds['mean_speed'] = speeds['mean_speed'].str.replace('[', '')
speeds['mean_speed'] = speeds['mean_speed'].str.replace(']', '')

# %%
speeds['std_speed'] = speeds['std_speed'].str.replace('[', '')
speeds['std_speed'] = speeds['std_speed'].str.replace(']', '')

# %%
speeds.head()
# Out:
#    location index        lat         lon  \
# 0               0 -38.100617  145.488326
# 1               1 -38.062604  145.367474
# 2               2 -38.357822  144.757135
# 3               3 -38.355186  144.752776
# 4               4 -38.351950  144.918912
#
#                                           mean_speed  \
# 0  73.82, 82.73, 84.695, 79.11, 76.4425, 66.62, 5...
# 1  56.12142857142857, 56.995000000000005, 70.1566...
# 2  65.52666666666666, 59.155, 46.449999999999996,...
# 3  76.262, 72.418, 68.33, 73.508, 77.43, 76.47, 7...
# 4  58.82400000000001, 55.13249999999999, 50.87999...
#
#                                            std_speed  week_hour
# 0  0.0, 0.0, 5.225000000000001, 11.54999999999999...          0
# 1  11.149351587259527, 23.845000000000002, 9.8312...          0
# 2  2.6402819714736676, 2.6219982837522977, 17.928...          0
# 3  1.930444508396961, 2.806730482251543, 4.724785...          0
# 4  4.580648862333807, 4.693273777439369, 18.31367...          0

# %%
speeds_.to_csv('speeds_processed2.csv', index=False)
